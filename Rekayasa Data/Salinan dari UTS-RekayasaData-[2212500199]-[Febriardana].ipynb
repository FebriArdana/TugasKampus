# %% [markdown]
# <a href="https://www.youtube.com/channel/UC80kXszNqAdWGTHFBcOKVdg"><img src="https://lh3.googleusercontent.com/3BGYLiEKEvFZ0u6eLcDbKvad__jwIRs30D19_ttfwuMv2TrJ3qovD_Lb_HGF4QvSCeVYoE2Ay6Hkfx0wN0LFV1VvILg7XIdrqR7bE9EtnbF2SwYIueV1-B33aomEwjTmkAKDY4TYopVfaSbfsBWzwfOXpoKy_ASFSrjKt_2p_E35fyTkTbES2t9GUnZ25bMjAe_Y4xqfkw-8lRqK9zCYVwlcD_e2YXUlNXs8ubJCHwZp3MAdPL3kWzLMnuVAKsiORvjt_IgCVINNcDAqfak56arvmtg4MXpcbyKSeYK2A33p0jcFnOkgddq3KhABVNqb0PRM7inpysBXMJ7-u7Q__Y4LVGdFh_gTmuPcxHQZXqS10kU_K86bOQtgqY5m9DjJ5Ixd--sxiR4evRr4LnjDH-9L-6Rcu4EZI6LXMxlANCuFGuTLgIIqrq6qgIliinjuxyuwsX-cl-pE_Y3TBcZ5dum52_O8HtkuPo3NOQXD0Pg4ZfQV11CSkeD-82HaONupDREROrrgFOriOYljzSj4438GSaK4IUTfDjP1UFMKnA6QuZGhSA0noStBSeIwTitSUsHbspxGwYm05Of9UiP-vpvhB5zGDUWl2gLpPsXxz6SDNlDGsVFekX81jNOrFnDzj-Me98FgK4AAmW4Of6Z8LN1ZjBw1MdFwGabLN94tHUMg0sPf-UJFbw5XqN0spoltuB8YmAGSyIWLHoC4eVuARcEX=w1659-h300-no?authuser=0" align="center"></a>

# %% [markdown]
# # Ujian Tengah Semester: Bagian 2
#
# * Mata Kuliah: Rekayasa Data
# * Kelompok: AA
# * Semester: Genap 2023/2024
# * Dosen: Dr. Ir. Achmad Solichin, S.Kom., M.T.I.

# %% [markdown]
# **Petunjuk Pengerjaan Soal**
#
# Kerjakan setiap perintah sesuai petunjuk / permintaan di setiap bagian. Setelah selesai, Anda dapat langkah sbb:
# 1. Sharing file Google Colabs dengan klik "**Bagikan**" yang ada di pojok kanan atas, tambahkan email achmad.solichin@budiluhur.ac.id (lihat contoh gambar di bawah ini)
# 2. **Salin tautan / link** Google Colabs **diunggah melalui elearning**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #0. Persiapan

# %% [markdown]
# ##Tuliskan biodata Anda dengan benar:

# %%
#NIM    : 2212500199
#NAMA   : FEBRI ARDANA
#EMAIL  : 2212500199@student.budiluhur.ac.id

# %% [markdown]
# ##Import Library
#
# Tuliskan perintah untuk mengimport library `pandas`, `numpy` dan library lain yang Anda perlukan

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ##Soal 1. Load dataset (nilai = 15)
#
# Tuliskan perintah untuk mengunduh dan me-load dataset berikut ini dari Kaggle menggunakan API: https://www.kaggle.com/datasets/yasserh/titanic-dataset. Simpan / load dataset ke Google Colabs dan simpan sebagai file `Titanic-Dataset.csv`

# %%
# !kaggle datasets download -d yasserh/titanic-dataset
# Out:
# Dataset URL: https://www.kaggle.com/datasets/yasserh/titanic-dataset
# License(s): CC0-1.0
# ...
#   0% 0.00/22.0k [00:00<?, ?B/s]
# 100% 22.0k/22.0k [00:00<00:00, 5.67MB/s]

# %%
import zipfile
zip_ref = zipfile.ZipFile('titanic-dataset.zip', 'r')
zip_ref.extractall('/content')
zip_ref.close()

# %% [markdown]
# ##Soal 2. Menampilkan Data (nilai 15)

# %% [markdown]
# Tampilkan data (5 teratas + 5 terbawah)

# %%
df = pd.read_csv('Titanic-Dataset.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# Tampilkan data 7 teratas

# %%
df.head(7)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# ...

# %% [markdown]
# Tampilkan data 10 terbawah

# %%
df.tail(10)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 881          882         0       3                        Markun, Mr. Johann
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 883          884         0       2             Banfield, Mr. Frederick James
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %% [markdown]
# #Soal 3. Mengambil Kolom Tertentu (nilai = 15)

# %% [markdown]
# Ambil dan tampilkan kolom `Name` dari dataset Titanic tersebut

# %%
name = df[['Name']]
name
# Out:
#                                                   Name
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# ..                                                 ...
# 886                              Montvila, Rev. Juozas
# 887                       Graham, Miss. Margaret Edith
# 888           Johnston, Miss. Catherine Helen "Carrie"
# 889                              Behr, Mr. Karl Howell
# 890                                Dooley, Mr. Patrick
#
# [891 rows x 1 columns]

# %% [markdown]
# Ambil dan tampilkan kolom `Name` dan `Survived` dari dataset

# %%
nv = df[['Name','Survived']]
nv
# Out:
#                                                   Name  Survived
# 0                              Braund, Mr. Owen Harris         0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...         1
# 2                               Heikkinen, Miss. Laina         1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)         1
# 4                             Allen, Mr. William Henry         0
# ..                                                 ...       ...
# 886                              Montvila, Rev. Juozas         0
# 887                       Graham, Miss. Margaret Edith         1
# 888           Johnston, Miss. Catherine Helen "Carrie"         0
# 889                              Behr, Mr. Karl Howell         1
# 890                                Dooley, Mr. Patrick         0
#
# [891 rows x 2 columns]

# %% [markdown]
# #Soal 4. Pemahaman dan Visualisasi Data (nilai 30)
#
# Tuliskan perintah untuk menampilkan jumlah baris dataset

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# Tuliskan perintah untuk menampilkan nilai rata-rata umur penumpang (kolom `Age`)

# %%
df[['Age']].describe()
# Out:
#               Age
# count  714.000000
# mean    29.699118
# std     14.526497
# min      0.420000
# 25%     20.125000
# 50%     28.000000
# 75%     38.000000
# max     80.000000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Age'].plot(kind='hist', bins=20, title='Age')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_1['Age'].plot(kind='line', figsize=(8, 4), title='Age')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %% [markdown]
# Tuliskan perintah untuk menampilkan jumlah data untuk setiap jenis kelamin (kolom `Sex`). Sajikan dalam bentuk tabel.

# %%
df[['Sex']].describe()
# Out:
#          Sex
# count    891
# unique     2
# top     male
# freq     577

# %% [markdown]
# Tuliskan perintah untuk menampilkan grafik pie (Pie chart) yang menyajikan total data per jenis kelamin (kolom `Sex`).

# %%
import matplotlib.pyplot as plt

Sex = ('count','unique','top','freq')
votes = (891, 2, 1, 577)

plt.pie(
    votes,
    labels=Sex,
)
plt.show()

# %% [markdown]
# #Soal 5. Pembersihan Data (nilai = 25)

# %% [markdown]
# Tuliskan perintah untuk menampilkan total data yang **kosong** (NULL) untuk setiap kolom dataset

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# Untuk setiap nilai pada kolom `Age` yang kosong (NULL), isikan (ganti) dengan nilai rata-rata dari kolom `Age`. Tuliskan perintah dan tampilkan hasilnya.

# %%
rata_rata = df['Age'].mean()
df['Age'].fillna(rata_rata, inplace=True)
df.to_csv('titanic_updated.csv', index=False)
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# ## Terima kasih, selamat mengerjakan!
#
# Soal ini dibuat oleh: <a href = "http://achmatim.net">Dr. Achmad Solichin</a>.
#
# <hr>
# Copyright &copy; 2024 [Achmatim.Net](http://achmatim.net). This notebook and its source code are released under the terms of the CC License.​
