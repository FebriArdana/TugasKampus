# %% [markdown]
# <a href="https://colab.research.google.com/github/aliyaaliyal/mesin-learning/blob/main/Gojek_app_review_machine_learning_SVM_Random_Forest_Naive_Bayes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
# !pip install google-play-scraper
# Out:
# Requirement already satisfied: google-play-scraper in /usr/local/lib/python3.10/dist-packages (1.2.6)

# %%
#from google_play_scraper import app

import pandas as pd

import numpy as np

# %% [markdown]
# # Scrapping 2000 data review gojek

# %%
from google_play_scraper import Sort, reviews

result, continuation_token = reviews(
    'com.grabtaxi.passenger',
    lang='id',
    country='id',
    sort=Sort.MOST_RELEVANT,
    count=2000, # defaults to 100
    filter_score_with=None
)

# %%
print(result[0])
# Out:
# {'reviewId': '85a7df87-572c-4d06-9f11-e5e457eabc0a', 'userName': 'Wisnu 123', 'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjWIpY5PKVwDdExmfVj3mh37FYtLqVBu67caQyVc3BBITXk_xGQS', 'content': 'Aplikasinya bagus dan tampilan antarmukanya juga bagus. Tidak ada kendala sama sekali dalam menggunakan aplikasi ini. Saya sangat menyukainya pada saat memesan makanan, karena ongkirnya murah dan terdapat berbagai pilihan pengantaran dengan biaya yang berbeda dan waktu pengiriman yang berbeda juga. Drivernya juga ramah.', 'score': 5, 'thumbsUpCount': 826, 'reviewCreatedVersion': '5.304.1', 'at': datetime.datetime(2024, 5, 8, 14, 52, 50), 'replyContent': 'Hi Kak. Terima kasih sudah jadi pengguna setia Grab yaa 🥰 Stay safe dan sehat-sehat terus Kak 🤗💚\n', 'repliedAt': datetime.datetime(2024, 5, 8, 23, 57, 11), 'appVersion': '5.304.1'}

# %%
data = pd.DataFrame(np.array(result), columns=['review'])

data = data.join(pd.DataFrame(data.pop('review').tolist()))

data
# Out:
#                                  reviewId              userName  \
# 0    85a7df87-572c-4d06-9f11-e5e457eabc0a             Wisnu 123
# 1    1aef1643-61ea-4fe6-a537-98b272f43f7f       Pengguna Google
# 2    37cf74ff-148e-4e62-9d79-3011dd05a872            Faturachma
# 3    083e7775-a884-4310-ab63-19bb40e38e89        Randi Kusmawan
# 4    ddf3119f-df94-4e66-801c-b972ef603cff           Zidan Cilok
# ..                                    ...                   ...
# 592  8e4e9bab-68f3-41da-8f13-e0c45589186c      Hendra Keksianto
# 593  27e668e7-9730-48ca-86b3-e8b67faf4bb6              zakiyyah
# 594  fc61d18b-193f-468f-9381-6179c7242bc5  RYO ROSANDHY MASHEZA
# 595  fe8f354f-d90f-425b-afab-70c39e40073d   Rani Putri Nurjulia
# 596  84b07744-b975-4fe4-96fa-e0ad517ba842           Gus Ehanner
#
#                                              userImage  \
# 0    https://play-lh.googleusercontent.com/a-/ALV-U...
# 1    https://play-lh.googleusercontent.com/EGemoI2N...
# 2    https://play-lh.googleusercontent.com/a-/ALV-U...
# 3    https://play-lh.googleusercontent.com/a-/ALV-U...
# 4    https://play-lh.googleusercontent.com/a/ACg8oc...
# ..                                                 ...
# 592  https://play-lh.googleusercontent.com/a/ACg8oc...
# 593  https://play-lh.googleusercontent.com/a/ACg8oc...
# 594  https://play-lh.googleusercontent.com/a-/ALV-U...
# 595  https://play-lh.googleusercontent.com/a-/ALV-U...
# 596  https://play-lh.googleusercontent.com/a/ACg8oc...
#
#                                                content  score  thumbsUpCount  \
# 0    Aplikasinya bagus dan tampilan antarmukanya ju...      5            826
# 1    Aplikasi Grab ketika layar HP di kunci atau se...      2             80
# 2    Titik suka tidak sesuai padahal sudah saya ses...      3            298
# 3    Kacau......niat buru2 malah dapat driver yang ...      5             30
# 4    Driver ojek online merupakan bagian integral d...      5           1326
# ..                                                 ...    ...            ...
# 592  cepat, gesit, ramah pengemudinya, terima kasih...      5              0
# 593  sekarang sering gangguan trs ga bisa di buka a...      1              0
# 594  Alhamdulillah dr sisi penumpang tarif grab leb...      5             30
# 595  Tolong pihak grab, jngan bikin saya kesal. mas...      3              0
# 596  Mantap..pelayanan prima pesanan selalu cepat t...      5              1
#
#     reviewCreatedVersion                  at  \
# 0                5.304.1 2024-05-08 14:52:50
# 1                5.299.0 2024-04-03 19:13:18
# 2                5.299.0 2024-04-18 05:00:49
# 3                5.307.0 2024-05-29 12:52:32
# 4                5.302.0 2024-04-21 07:46:09
# ..                   ...                 ...
# 592              5.303.0 2024-05-02 11:45:16
# 593              5.303.0 2024-05-03 06:10:13
# 594              5.303.0 2024-05-02 09:43:55
# 595              5.304.0 2024-05-04 12:43:09
# 596              5.303.0 2024-05-06 04:20:54
#
#                                           replyContent           repliedAt  \
# 0    Hi Kak. Terima kasih sudah jadi pengguna setia... 2024-05-08 23:57:11
# 1    Halo Kak. Maaf ya buat engga nyaman 🙇‍♀️\nApab... 2024-04-04 07:16:29
# 2    Halo Kak. Maaf ya buat engga nyaman 🙇‍♀️\nApab... 2024-04-18 06:11:46
# 3                                                 None                 NaT
# 4                                                 None                 NaT
# ..                                                 ...                 ...
# 592                                               None                 NaT
# 593  Hai Kak. Sebelumnya mohon maaf atas ketidaknya... 2024-05-09 10:55:16
# 594                                               None                 NaT
# 595  Halo Kak, maaf ya jadi bikin nggak nyaman 🙇‍♀️... 2024-05-04 22:52:29
# 596  Hai Kak. Terima kasih sudah menjadi pengguna s... 2024-05-18 07:22:50
#
#     appVersion
# 0      5.304.1
# 1      5.299.0
# 2      5.299.0
# 3      5.307.0
# 4      5.302.0
# ..         ...
# 592    5.303.0
# 593    5.303.0
# 594    5.303.0
# 595    5.304.0
# 596    5.303.0
#
# [597 rows x 11 columns]

# %%
scrappeddata1 = data[['content','score','at']]
sorteddata = scrappeddata1.sort_values(by='at', ascending=True) #Sort by Newest, change to True if you want to sort by Oldest.
sorteddata.head()
# Out:
#                                                content  score  \
# 348  Tadinya suka sama aplikasi ini karena mempermu...      1
# 189  Aplikasi lumayan bagus. Untuk iklan, mohon jgn...      4
# 345  Tampilan di menu grab kurang nyaman, bagian pr...      2
# 502  Kayaknya aku agak paham dgn beda pengiriman he...      2
# 349  Saya ga paham sama aplikasi ini. Alamat sudah ...      2
#
#                      at
# 348 2023-12-18 10:03:16
# 189 2023-12-20 04:06:47
# 345 2023-12-27 02:34:04
# 502 2023-12-28 10:18:43
# 349 2023-12-31 11:05:36

# %%
sorteddata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 597 entries, 348 to 547
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   content  597 non-null    object
#  1   score    597 non-null    int64
#  2   at       597 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), int64(1), object(1)
# memory usage: 18.7+ KB

# %%
sorteddata['Tahun'] = sorteddata['at'].dt.year
sorteddata['Bulan'] = sorteddata['at'].dt.month
sorteddata['Tanggal'] = sorteddata['at'].dt.day

# %%
sorteddata
# Out:
#                                                content  score  \
# 348  Tadinya suka sama aplikasi ini karena mempermu...      1
# 189  Aplikasi lumayan bagus. Untuk iklan, mohon jgn...      4
# 345  Tampilan di menu grab kurang nyaman, bagian pr...      2
# 502  Kayaknya aku agak paham dgn beda pengiriman he...      2
# 349  Saya ga paham sama aplikasi ini. Alamat sudah ...      2
# ..                                                 ...    ...
# 262  aplikasi bagus tapi akhir" ini nunggu pesanan ...      1
# 42   Sumpah yaa tiap order grab XL dapetnya vario.....      1
# 381  Aplikasinya sinyal bagus pake waifu tapi di bi...      1
# 80   Bnr2 kacau banget ini buat pendaftaran di kant...      2
# 547  gofood nya bagus tpi soal grab nya perlu d tin...      4
#
#                      at  Tahun  Bulan  Tanggal
# 348 2023-12-18 10:03:16   2023     12       18
# 189 2023-12-20 04:06:47   2023     12       20
# 345 2023-12-27 02:34:04   2023     12       27
# 502 2023-12-28 10:18:43   2023     12       28
# 349 2023-12-31 11:05:36   2023     12       31
# ..                  ...    ...    ...      ...
# 262 2024-05-30 05:49:15   2024      5       30
# 42  2024-05-30 08:02:18   2024      5       30
# 381 2024-05-30 09:33:16   2024      5       30
# 80  2024-05-30 10:28:07   2024      5       30
# 547 2024-05-30 12:29:32   2024      5       30
#
# [597 rows x 6 columns]

# %%
df = sorteddata[['content','score','Tahun','Bulan','Tanggal']]
df
# Out:
#                                                content  score  Tahun  Bulan  \
# 348  Tadinya suka sama aplikasi ini karena mempermu...      1   2023     12
# 189  Aplikasi lumayan bagus. Untuk iklan, mohon jgn...      4   2023     12
# 345  Tampilan di menu grab kurang nyaman, bagian pr...      2   2023     12
# 502  Kayaknya aku agak paham dgn beda pengiriman he...      2   2023     12
# 349  Saya ga paham sama aplikasi ini. Alamat sudah ...      2   2023     12
# ..                                                 ...    ...    ...    ...
# 262  aplikasi bagus tapi akhir" ini nunggu pesanan ...      1   2024      5
# 42   Sumpah yaa tiap order grab XL dapetnya vario.....      1   2024      5
# 381  Aplikasinya sinyal bagus pake waifu tapi di bi...      1   2024      5
# 80   Bnr2 kacau banget ini buat pendaftaran di kant...      2   2024      5
# 547  gofood nya bagus tpi soal grab nya perlu d tin...      4   2024      5
#
#      Tanggal
# 348       18
# 189       20
# 345       27
# 502       28
# 349       31
# ..       ...
# 262       30
# 42        30
# 381       30
# 80        30
# 547       30
#
# [597 rows x 5 columns]

# %%
df.to_csv('grab.csv', index=False)

# %%
df['score'].value_counts()
# Out:
# score
# 1    299
# 5    124
# 2     74
# 3     62
# 4     38
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 597 entries, 348 to 547
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   content  597 non-null    object
#  1   score    597 non-null    int64
#  2   Tahun    597 non-null    int32
#  3   Bulan    597 non-null    int32
#  4   Tanggal  597 non-null    int32
# dtypes: int32(3), int64(1), object(1)
# memory usage: 21.0+ KB

# %% [markdown]
# # Jumlah Review berdasarkan score/rating

# %%
df.groupby(['score']).size().plot(kind = "bar")
# Out:
# <Axes: xlabel='score'>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Distribusi Score/Rating

# %%
# use the groupby() function to group island column
# and apply size() function
# size() is equivalent to counting the distinct rows
import seaborn as sns
result = df.groupby(['score']).size()

# plot the result
sns.barplot(x = result.index, y = result.values)
# Out:
# <Axes: xlabel='score'>

# %% [markdown]
# # Kolom Sentimen
# Menambahkan kolom sentimen dengan kriteria, score 1-2 --> negatif dengan kode -1, score 3 adalah netral dengan kode angka 0 dan score 4-5 adalah positif dengan kode 1

# %%
sentimen = []
for index, row in df.iterrows():
    if row['score'] > 3 :
        sentimen.append(1)
    elif row['score'] == 3:
        sentimen.append(0)
    else:
        sentimen.append(-1)
df['sentiment'] = sentimen
df.head()
# Out:
#                                                content  score  Tahun  Bulan  \
# 348  Tadinya suka sama aplikasi ini karena mempermu...      1   2023     12
# 189  Aplikasi lumayan bagus. Untuk iklan, mohon jgn...      4   2023     12
# 345  Tampilan di menu grab kurang nyaman, bagian pr...      2   2023     12
# 502  Kayaknya aku agak paham dgn beda pengiriman he...      2   2023     12
# 349  Saya ga paham sama aplikasi ini. Alamat sudah ...      2   2023     12
#
#      Tanggal  sentiment
# 348       18         -1
# 189       20          1
# 345       27         -1
# 502       28         -1
# 349       31         -1

# %% [markdown]
# ## Distribusi Sentimen

# %%
df_new = df[['Tahun', 'Bulan', 'sentiment']]
#df_new
result = df_new.groupby(['sentiment']).size()

# plot the result
sns.barplot(x = result.index, y = result.values)
# Out:
# <Axes: xlabel='sentiment'>

# %%
#plot a bar graph to show count of tweet sentiment
fig = plt.figure(figuresize=(7,5))
color = ['green','grey','red']
df_new['sentiment'].value_counts().plot(kind='bar',color = color)
plt.title('Jumlah Review tiap Sentiment')
plt.ylabel('Jumlah')
plt.xlabel('Sentiment')
plt.grid(False)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-146-31473f035afa> in <cell line: 2>()
#       1 #plot a bar graph to show count of tweet sentiment
# ----> 2 fig = plt.figure(figuresize=(7,5))
#       3 color = ['green','grey','red']
#       4 df_new['sentiment'].value_counts().plot(kind='bar',color = color)
#       5 plt.title('Jumlah Review tiap Sentiment')
#
# NameError: name 'plt' is not defined

# %%
#pie chart to show percentage distribution of polarity
fig = plt.figure(figsize=(7,7))
colors = ('red', 'grey', 'green')
wp={'linewidth':2, 'edgecolor': 'black'}
tags=df_new['sentiment'].value_counts()
explode = (0.1,0.1,0.1)
tags.plot(kind='pie', autopct='%1.1f%%', shadow=True, colors=colors,
         startangle=90, wedgeprops=wp, explode=explode, label='')
plt.title('Distribution of sentiment')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-49-0fad158278cb> in <cell line: 2>()
#       1 #pie chart to show percentage distribution of polarity
# ----> 2 fig = plt.figure(figsize=(7,7))
#       3 colors = ('red', 'grey', 'green')
#       4 wp={'linewidth':2, 'edgecolor': 'black'}
#       5 tags=df_new['sentiment'].value_counts()
#
# NameError: name 'plt' is not defined

# %% [markdown]
# ## Distribusi Sentimen per tahun

# %%
import seaborn as sns
sns.countplot(data=df_new,x='Tahun',hue='sentiment')
# Out:
# <Axes: xlabel='Tahun', ylabel='count'>

# %%
df2 = df_new.groupby(['Tahun'])['Bulan'].count()
df2
# Out:
# Tahun
# 2023      5
# 2024    592
# Name: Bulan, dtype: int64

# %%
df3 = df_new.groupby(['Tahun','sentiment'])['sentiment'].count()
df3
# Out:
# Tahun  sentiment
# 2023   -1             4
#         1             1
# 2024   -1           369
#         0            62
#         1           161
# Name: sentiment, dtype: int64

# %%
import pandas as pd
import string
import nltk

# %%
df['sentiment'].value_counts()
# Out:
# sentiment
# -1    373
#  1    162
#  0     62
# Name: count, dtype: int64

# %% [markdown]
# # Tahapan Preprocessing

# %%
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %% [markdown]
# **Menghapus URL dari kolom konten**

# %%
df['content'] = df['content'].str.replace('https\S+', ' ', case=False)

# %% [markdown]
# **Merubah Teks Jadi Lower Case**

# %%
df['content'] = df['content'].str.lower()

# %% [markdown]
# **Menghapus mention**

# %%
df['content'] = df['content'].str.replace('@\S+', ' ', case=False)

# %% [markdown]
# **Menghapus Hashtag**

# %%
df['content'] = df['content'].str.replace('#\S+', ' ', case=False)

# %% [markdown]
# **menghapus next karakter**

# %%
df['content'] = df['content'].str.replace("\'\w+", ' ', case=False)

# %% [markdown]
# **Menghapus tanda baca**

# %%
df['content'] = df['content'].str.replace("[^\w\s]", ' ', case=False)

# %% [markdown]
# **Menghapus extra whitespace**

# %%
df['content'] = df['content'].str.replace("\s(2)", ' ', case=False)

# %% [markdown]
# **Tokenizing**

# %%
# impor word_tokenize dari modul nltk
from nltk.tokenize import word_tokenize

# %%
#df['content']=df.apply(lambda row: nltk.word_tokenize(row['content']), axis=1)
from nltk.tokenize import RegexpTokenizer
regexp = RegexpTokenizer('\w+')
df['content_token']=df['content'].apply(regexp.tokenize)
df.head(3)
# Out:
#                                                content  score  Tahun  Bulan  \
# 348  tadinya suka sama aplikasi ini karena mempermu...      1   2023     12
# 189  aplikasi lumayan bagus. untuk iklan, mohon jgn...      4   2023     12
# 345  tampilan di menu grab kurang nyaman, bagian pr...      2   2023     12
#
#      Tanggal  sentiment                                      content_token
# 348       18         -1  [tadinya, suka, sama, aplikasi, ini, karena, m...
# 189       20          1  [aplikasi, lumayan, bagus, untuk, iklan, mohon...
# 345       27         -1  [tampilan, di, menu, grab, kurang, nyaman, bag...

# %% [markdown]
# # Filtering (Stopword Removal)
#
# **Filtering** adalah tahap mengambil kata-kata penting dari hasil token dengan menggunakan algoritma stoplist (membuang kata kurang penting) atau wordlist (menyimpan kata penting).
#
# **Stopword** adalah kata umum yang biasanya muncul dalam jumlah besar dan dianggap tidak memiliki makna. Contoh stopword dalam bahasa Indonesia adalah “yang”, “dan”, “di”, “dari”, dll. Makna di balik penggunaan stopword yaitu dengan menghapus kata-kata yang memiliki informasi rendah dari sebuah teks, kita dapat fokus pada kata-kata penting sebagai gantinya.
#
# Contoh penggunaan filtering dapat kita temukan pada konteks mesin pencarian. Jika permintaan pencarian anda adalah “apa itu pengertian manajemen?” tentunya anda ingin sistem pencarian fokus pada memunculkan dokumen dengan topik tentang “pengertian manajemen” di atas dokumen dengan topik “apa itu”. Hal ini dapat dilakukan dengan mencegah kata dari daftar stopword dianalisa.
#
# https://www.kirenz.com/post/2021-12-11-text-mining-and-sentiment-analysis-with-nltk-and-pandas-in-python/text-mining-and-sentiment-analysis-with-nltk-and-pandas-in-python/

# %%
import nltk

nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords

# Make a list of english stopwords
stopwords = nltk.corpus.stopwords.words("indonesian")
# Extend the list with your own custom stopwords
my_stopwords = ['grab']
stopwords.extend(my_stopwords)

# %%
# Remove stopwords
df['content_token'] = df['content_token'].apply(lambda x: [item for item in x if item not in stopwords])
df.head(3)
# Out:
#                                                content  score  Tahun  Bulan  \
# 348  tadinya suka sama aplikasi ini karena mempermu...      1   2023     12
# 189  aplikasi lumayan bagus. untuk iklan, mohon jgn...      4   2023     12
# 345  tampilan di menu grab kurang nyaman, bagian pr...      2   2023     12
#
#      Tanggal  sentiment                                      content_token
# 348       18         -1  [suka, aplikasi, mempermudah, kesini, eror, ik...
# 189       20          1  [aplikasi, lumayan, bagus, iklan, mohon, jgn, ...
# 345       27         -1  [tampilan, menu, grab, nyaman, promo, mencolok...

# %% [markdown]
# # Stemming sastrawi

# %% [markdown]
# Sastrawi Python adalah library python sederhana yang memungkinkan Anda untuk mereduksi kata-kata infleksi dalam Bahasa Indonesia (Bahasa Indonesia) ke bentuk dasarnya (stem). Ini adalah port Python dari proyek Sastrawi asli yang ditulis dalam PHP (kredit diberikan kepada penulis asli dan kontributor Sastrawi PHP). https://medium.com/@93Kryptonian/stemming-with-sastrawi-877cc40a37ad

# %% [markdown]
# Stemming adalah teknik pemrosesan bahasa alami yang menurunkan infleksi kata ke bentuk akarnya, sehingga membantu dalam pra-pemrosesan teks, kata, dan dokumen untuk normalisasi teks.
#
# Menurut Wikipedia, infleksi adalah proses di mana sebuah kata dimodifikasi untuk mengkomunikasikan banyak kategori tata bahasa, termasuk tegang, kasus, suara, aspek, orang, jumlah, jenis kelamin, dan suasana hati. Jadi, meskipun sebuah kata mungkin ada dalam beberapa bentuk infleksi, memiliki beberapa bentuk infleksi di dalam teks yang sama menambah redundansi pada proses NLP.
#
# Akibatnya, kami menggunakan stemming untuk mengurangi kata ke bentuk dasar atau stem, yang mungkin atau mungkin bukan kata yang sah dalam bahasa tersebut.
#
# Misalnya, batang dari ketiga kata ini, koneksi, terhubung, menghubungkan, adalah "menghubungkan". Di sisi lain, akar masalah, masalah, dan masalah adalah "masalah", yang bukan kata yang dikenal.

# %%
# !pip install Sastrawi
# Out:
# Requirement already satisfied: Sastrawi in /usr/local/lib/python3.10/dist-packages (1.0.1)

# %%
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory

# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# %%
df['stemmed'] = df['content_token'].apply(lambda x: [stemmer.stem(y) for y in x]) # Stem every word.
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3652         try:
# -> 3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'content_token'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-150-e601bf7ccb18> in <cell line: 1>()
# ----> 1 df['stemmed'] = df['content_token'].apply(lambda x: [stemmer.stem(y) for y in x]) # Stem every word.
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3759             if self.columns.nlevels > 1:
#    3760                 return self._getitem_multilevel(key)
# -> 3761             indexer = self.columns.get_loc(key)
#    3762             if is_integer(indexer):
#    3763                 indexer = [indexer]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
# -> 3655             raise KeyError(key) from err
#    3656         except TypeError:
#    3657             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'content_token'

# %%
df.head(5)

# %% [markdown]
# ## Hanya yang lebih dari 3 kata yang dipakai

# %%
df['text_string'] = df['stemmed'].apply(lambda x: ' '.join([item for item in x if len(item)>3]))

# %%
df.head(5)
# Out:
#                                                content  score  Tahun  Bulan  \
# 189  aplikasi lumayan bagus. untuk iklan, mohon jgn...      4   2023     12
# 188  aplikasi nya sangat sangat membantu dan mudah ...      1   2024      2
# 106  sistemnya nyari alamat diketik ga bisa. peta t...      1   2024      3
# 182  semoga diperbaiki dengan baik,saat hujan susah...      1   2024      3
# 122  aplikasi tidak profesional, komplain dari cust...      1   2024      3
#
#      Tanggal  sentiment                                      content_token  \
# 189       20          1  [aplikasi, lumayan, bagus, iklan, mohon, jgn, ...
# 188        5         -1  [aplikasi, nya, membantu, mudah, edit, pake, g...
# 106        6         -1  [sistemnya, nyari, alamat, diketik, ga, peta, ...
# 182        9         -1  [semoga, diperbaiki, hujan, susah, banget, dap...
# 122        9         -1  [aplikasi, profesional, komplain, customer, ta...
#
#                                                stemmed  \
# 189  [aplikasi, lumayan, bagus, iklan, mohon, jgn, ...
# 188  [aplikasi, nya, bantu, mudah, edit, pake, grab...
# 106  [sistem, nyari, alamat, ketik, ga, peta, updat...
# 182  [moga, baik, hujan, susah, banget, dapet, grab...
# 122  [aplikasi, profesional, komplain, customer, ta...
#
#                                            text_string
# 189  aplikasi lumayan bagus iklan mohon taruh tombo...
# 188  aplikasi bantu mudah edit pake grab food kirim...
# 106  sistem nyari alamat ketik peta update ubah pro...
# 182  moga baik hujan susah banget dapet grab emang ...
# 122  aplikasi profesional komplain customer tanggap...

# %%
#df.to_csv('review_gojek_stemmed.csv') #write dataframe into csv file
df = pd.read_csv('/content/grab.csv',index_col=0) #reads csv file

# %%
df.head()
# Out:
#                                                     score  Tahun  Bulan  \
# content
# Tadinya suka sama aplikasi ini karena mempermud...      1   2023     12
# Aplikasi lumayan bagus. Untuk iklan, mohon jgn ...      4   2023     12
# Tampilan di menu grab kurang nyaman, bagian pro...      2   2023     12
# Kayaknya aku agak paham dgn beda pengiriman hem...      2   2023     12
# Saya ga paham sama aplikasi ini. Alamat sudah s...      2   2023     12
#
#                                                     Tanggal
# content
# Tadinya suka sama aplikasi ini karena mempermud...       18
# Aplikasi lumayan bagus. Untuk iklan, mohon jgn ...       20
# Tampilan di menu grab kurang nyaman, bagian pro...       27
# Kayaknya aku agak paham dgn beda pengiriman hem...       28
# Saya ga paham sama aplikasi ini. Alamat sudah s...       31

# %%
df.groupby(['Bulan','Tanggal'])
print(df.groupby(['Bulan','Tanggal']).groups)
# Out:
# {(1, 4): ['aplikasi nya berrrrraaaaaatt. Ijo2 sebelah jauh lebih ringan dan cepat. Tarif so so lah, kompetitif. Kalo lagi buth cepet, dan ternyata aplikasi minta diupdate, gabisa ditunda nanti, harus update dulu baru bisa dipakai. ga efisien dan ga mobile. Jauh dibanding tetangga sebelah. Aplikasi susah banget kalo perlu bantuan, e-receipt susah, verifikasi email susah. Serba susah pakai GRAB. Sebel guah'], (1, 11): ['Selamat malam. Sebelumnya ijin memberikan bintang satu. Kebetulan baru saja ada kendala dalam membuka aplikasi Grab, soalnya ngebug dan tiba-tiba keluar + not responding. Sudah gitu, petanya tidak bisa digunakan karena tidak bisa menambah tujuan baru'], (1, 14): ['Makin kesini, makin banyak bug atau mungkin "makin dibatesin" dan makin ribet. dulu mau pesen makan buat keluarga yang jauh beda pulau masih bisa. UI nya masih user friendly banget. Pilih lokasinya gampang (dari lokasi tersimpan). Sekarang? Mau pesen makan buat keluarga jauh, ribeet banget.... dan error!! Pilih lokasi tersimpan gak bisa (karena lokasi tidak sesuai dengan kondisi saat ini), milih lokasi harus pake peta, kudu ngetik kebutuhan mau cari apa. Eh ujung2nya "ups, ada yg salah". Hadeh'], (1, 18): ['alamat yg di cari tida akurat dan ga tepat jauh dari posisi yg di ketik di peta tolong perbaiki lg kasian sama ojek nya menuju alamat yg salah.kenapa kalau saya ngetik alamat saya di apk grab ini ga ada malah di arahkan ke alamat yg jauh dari tempat tinggal .tolong catat baik baik coba perbaiki lagi .yg saya masalahkan bukan penumpang atau grab nya .iklan grab selalu muncul di luar apknya payah'], (1, 19): ['Bintang empat jadi bintang satu. Makasih ya udah pesen makan berkali-kali + banyak bug dan eror gajelas yang bikin gabisa order lalu akhirnya pesenan harus dibatalkan berkali-kali semua padahal saya belinya ke toko yang deket. Ngapain saya cape-cape langganan unlimited ujungnya kek begini. Saatnya uninstall 😊'], (1, 20): ['Kecewa dengan pelayanan GRAB FOOD. Hampir 1 jam driver tidak pick up pesanan saya yg sudah selesai dibuat. Tidak ada konfirmasi pula dari driver dan tidak bisa ganti driver. Saya tlp pusat bantuan, pulsa terpotong banyak. Dan tiba2 pesanan dibatalkan sepihak, bukan cari driver pengganti. Terus tiba2 penjualnya WA saya minta tanggung jawab bayarin pesanan yg udh dibatalkan sepihak oleh GRAB FOOD. Sementara saya udh pesen di penjual yg lain. Jadi double bayar. Kapok pake GRAB! JELEK.'], (2, 2): ['Makin kesini makin ribet, pemesanan pengiriman kebanyakan pilihan. Pas pilih hemat ternyata lama banget, niat batalkan ga bisa keterangan pesanan sudah dibuat. Padahal Saya chat restonya belum ada pesanan atas nama Saya. Tolonglah kalo mau naikin tarif ongkir ya naikin aja jangan kebanyakan pilihan pengiriman.'], (2, 4): ['Sering error mo buru2 cari2 makanan eh diklik loading mulu tokonya gak kebuka-buka. Trus maps juga aneh banget, mo ngatur titik aja susah banget. Bukan karena sinyal, app lain gak ada masalah.'], (2, 5): ['Aplikasi nya sangat sangat membantu dan mudah digunakan 👍👍 EDIT: saya sudah lama pake grab food, tapi makin sini pengiriman nya lama banget bisa 1jam lebih bahkan pernah sampe 2jam an, awal awal positif thinking mungkin lagi penuh, tapi beberapa kali pesen setelahnya tetep lama entah sengaja atau gimana tapi kecewa selalu melebihi estimasi!!! Uninstall dah....'], (2, 14): ['bintang 1 karena apl tidak menyediakan informasi lokasi yang detail,driver seenaknya sendiri,driver sengaja terlambat,driver tidak paham penggunaan aplikasi map di dalam fiturnya,driver banyak alasan,driver sering mengecewakan,harga murah tapi tidak sesuai ekspektasi,dan banyak masalah lainnya'], (2, 15): ['Sebenarnya suka banget sama apknya, tapi yang PALING BIKIN KESEL, bisa ga motor drivernya itu yang sesuai sama di apk, ini di apk keterangan motor sama pas datengnya beda. Sering juga di marahin karna drivernya kelamaan nunggu padahal karna kita ga tau motornya beda sama yang dipake. PLEASE BANGET INI!!! Tolong di perhatikan ya!'], (2, 25): ['k ...
# di map banyak driver yang dekat dengan posisi saya. Mental terus ke yg
# jauh, kacau pokoknya. Kapan fitur grabnow launching di sukabumi? Biar saya
# lebih mudah memesan.', 'Saya kecewa dengan apk grab baru jg pilih menu blum apa apa langsung order dengan nominal yg gede tanpa ada order dan ga bisa di batalkan padahal sudah pusat bantuan juga tidak ngaruh sangat kecewa banget', 'cepat dan tepat. good job. sering2 ada vocer promonya ya.', 'Kalau lagi promo murah nya kebangetan. Tapi kalau tidak promo mahalnya juga kebangetan 🙏', 'Cuma mau kasih info kalau resto yang sudah prioritas, komisinya sampai 37% untuk apk.. Kalau makan di tempat mah murah meriah.. 😇', 'sejak pertama menggunakan grab -+ 7, tidak mengalami hambatan, tks'], (5, 30): ['grap sangat membantu jika ingin bepergian kemana". dan juga harganya sangat terjangkau.', 'Sering dpt driver fiktif,orderan diambil tp ga dtg²,ga bergerak dr titik.dichat ga respon,bikin org telat msk kerja.hrs qt yg cancel krn dy ngegantungin orderan.tlg ditindak driver yg bgtu,merugikan pengguna.', 'Mohon lah pak segera merespon masalah yang saya kirim lewat gmail. Susah sekarang menemukan orang yang jujur. Nomor wa yang melakukan pengantaran pun tidak ada. Mau menghubungi pun susah. Mohon di tingkatkan aplikasinya menggunaka wa', 'Kembalikan lagi sistem bonus untuk driver seperti awal , jika dapat 30 orderan dapat bonus 300rb .. HARUS DIADAKAN KEMBALI DALAM WAKTU DEKAT JIKA TIDAK AKAN ADA DEMO DALAM WAKTU DEKAT', 'Tolong diperbaiki Ketika pendaftaran akun, akun Gmail ga pernah dipake untuk daftar kenapa akun diberhentikan?', 'sangat sabar ,baik , pokoknya the best kali lah kalok abang ini , ramah lagi ,jadi gak bosan di perjalanan', 'aplikasi bagus tapi akhir" ini nunggu pesanan entah makanan atau minuman lama banget hampir 1jam setengah baru dianter..', 'Sumpah yaa tiap order grab XL dapetnya vario.. udah dicancel berkali kali ttp dapetnya vario, pdhl wes bayar mahal buat kenyamanan, sekalinya dpt kayak pcx apa nmax yg dicancel sm drivernya, eh diganti dpt vario lagi.. gedeg lama lama', 'Aplikasinya sinyal bagus pake waifu tapi di bilang jelek terus enggak bisa order mobil grab', 'Bnr2 kacau banget ini buat pendaftaran di kantor grab nya d Bali, kayaknya perlu di benahi dech kantor grab d Bali,dan juga katanya bisa online ternyata gak bisa, coba dech d perbaharui cara pendaftaran di kantor grab nya biar gak kacau balau,sekali2 d audit gitu kantor nya buat cek cara pelayanannya', 'gofood nya bagus tpi soal grab nya perlu d tingkatkan lagi'], ...}

# %% [markdown]
# # WORDCLOUD

# %% [markdown]
# wordcloud digunakan untuk memunculkan citraan visual dari sebuah teks tertulis kemudian dapat dijadikan sebagai sebuah alat bantu dalam melakukan analisis teks.
# kata-kata yang ada digambarkan kedalam suatu visualisasi dimana besar kecilnya huruf bergantung pada frekuensi munculnya kata tersebut didalam teks.
# singkatnya adalah kata terbesar adalah kata yang paling sering muncul dalam suatu data.

# %%
# !pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in /usr/local/lib/python3.10/dist-packages (1.9.3)
# Requirement already satisfied: numpy>=1.6.1 in /usr/local/lib/python3.10/dist-packages (from wordcloud) (1.25.2)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from wordcloud) (9.4.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from wordcloud) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (24.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)

# %% [markdown]
# # wordcloud sentimen positif

# %%
df_a=df[df['sentiment']==1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3652         try:
# -> 3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'sentiment'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-144-2670e99b2bca> in <cell line: 1>()
# ----> 1 df_a=df[df['sentiment']==1]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3759             if self.columns.nlevels > 1:
#    3760                 return self._getitem_multilevel(key)
# -> 3761             indexer = self.columns.get_loc(key)
#    3762             if is_integer(indexer):
#    3763                 indexer = [indexer]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
# -> 3655             raise KeyError(key) from err
#    3656         except TypeError:
#    3657             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'sentiment'

# %%
all_words_lem = ' '.join([word for word in df_p['text_string']])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-142-c3d8acded37a> in <cell line: 1>()
# ----> 1 all_words_lem = ' '.join([word for word in df_p['text_string']])
#
# NameError: name 'df_p' is not defined

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from wordcloud import WordCloud

wordcloud = WordCloud(background_color='white', width=800, height=500, random_state=21, max_font_size=130).generate(all_words_lem)

plt.figure(figsize=(20, 10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off');

# %% [markdown]
# # wordcloud sentimen negatif

# %%
df_neg=df[df['sentiment']==-1]
all_words_lemneg = ' '.join([word for word in df_neg['text_string']])

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from wordcloud import WordCloud

wordcloud = WordCloud(background_color='white', width=800, height=500, random_state=21, max_font_size=130).generate(all_words_lemneg)

plt.figure(figsize=(20, 10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off');
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2bfdb45354f1> in <cell line: 5>()
#       3 from wordcloud import WordCloud
#       4
# ----> 5 wordcloud = WordCloud(background_color='white', width=800, height=500, random_state=21, max_font_size=130).generate(all_words_lemneg)
#       6
#       7 plt.figure(figsize=(20, 10))
#
# NameError: name 'all_words_lemneg' is not defined

# %% [markdown]
# # wordcloud sentimen netral

# %%
df_net=df[df['sentiment']==0]
all_words_lemnet = ' '.join([word for word in df_net['text_string']])

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from wordcloud import WordCloud

wordcloud = WordCloud(background_color='white', width=800, height=500, random_state=21, max_font_size=130).generate(all_words_lemnet)

plt.figure(figsize=(20, 10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off');

# %%
df['text_string']
# Out:
# 8701    promo tentu ubah ubah cash back belanja alfama...
# 6636    saran tarif kemudi tolong perhati timbang kasi...
# 8638    aplikasi gocar driver fake tuyul order driver ...
# 5358    saran gambar food loadnya user proses pilih pe...
# 7854    beri promo customer sifat random alas promo ba...
#                               ...
# 4838        jelek saldo ilang muncul tolong kembali saldo
# 9079    gabisa pake voucher padah langgan ngeupgrade b...
# 846     cepat kali transfer gopay bank kamren proses s...
# 63      udah pakai later tetep limit naik2 kayak cuman...
# 776     habis date level turun juragan anak sultan lev...
# Name: text_string, Length: 10000, dtype: object

# %%
# Basic Operation
import pandas as pd
import numpy as np

# Text Preprocessing & Cleaning
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.corpus import stopwords
import re
from wordcloud import WordCloud,STOPWORDS
from nltk import SnowballStemmer


from sklearn.model_selection import train_test_split # Split Data
from imblearn.over_sampling import SMOTE # Handling Imbalanced

# Model Building
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import MultinomialNB
from xgboost import XGBClassifier
from sklearn.svm import SVC


from sklearn.metrics import classification_report , confusion_matrix , accuracy_score # Performance Metrics


# Data Visualization
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import seaborn as sns
import warnings


warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
X = df['text_string']
y = df['sentiment']

# %% [markdown]
# https://www.kaggle.com/code/hummetbelli/twitter-us-airline-sentiment-nlp-95-acc

# %% [markdown]
# # Penerapan TF-IDF
# Term frequency-inverse document frequency adalah text vectorizer yang mengubah teks menjadi vektor yang dapat digunakan. Ini menggabungkan 2 konsep, Term Frequency (TF) dan Document Frequency (DF).
#
# Frekuensi istilah adalah jumlah kemunculan istilah tertentu dalam dokumen. Frekuensi istilah menunjukkan seberapa penting istilah tertentu dalam sebuah dokumen. Frekuensi istilah mewakili setiap teks dari data sebagai matriks yang barisnya adalah jumlah dokumen dan kolomnya adalah jumlah istilah yang berbeda di seluruh dokumen.
#
# Frekuensi dokumen adalah jumlah dokumen yang mengandung istilah tertentu. Frekuensi dokumen menunjukkan seberapa umum istilah tersebut.
#
# Inverse document frequency (IDF) adalah bobot suatu term, hal ini bertujuan untuk mengurangi bobot suatu term jika kemunculan term tersebar di seluruh dokumen. IDF dapat dihitung sebagai berikut:
# ![rumus idf.webp](data:image/webp;base64,...)
#
#
# Dimana idfᵢ adalah skor IDF untuk term i, dfᵢ adalah jumlah dokumen yang mengandung term i, dan n adalah jumlah total dokumen. Semakin tinggi DF suatu term, semakin rendah IDF untuk term tersebut. Ketika jumlah DF sama dengan n yang berarti istilah tersebut muncul di semua dokumen, IDF akan menjadi nol, karena log(1) adalah nol, jika ragu masukkan saja istilah ini ke dalam daftar stopword karena tidak menyediakan banyak informasi.
#
# Skor TF-IDF seperti namanya hanyalah perkalian dari matriks frekuensi term dengan IDF-nya, dapat dihitung sebagai berikut:
#
# ![idf.png](data:image/png;base64,...)
#
# Dimana wᵢⱼ adalah skor TF-IDF untuk term i pada dokumen j, tfᵢⱼ adalah frekuensi term untuk term i pada dokumen j, dan idfᵢ adalah skor IDF untuk term i.

# %%
tfid = TfidfVectorizer()
X_final =  tfid.fit_transform(X)

# %% [markdown]
# # HANDLING IMBALANCE
# Dalam Machine Learning dan Data Science sering kita jumpai istilah yang disebut Distribusi Data Tidak Seimbang, umumnya terjadi ketika pengamatan di salah satu kelas jauh lebih tinggi atau lebih rendah dari kelas lainnya. Karena algoritma Machine Learning cenderung meningkatkan akurasi dengan mengurangi kesalahan, mereka tidak mempertimbangkan distribusi kelas.
#
# Masalah ini lazim dalam contoh-contoh seperti Deteksi Penipuan, Deteksi Anomali, Pengenalan wajah, dll.
#
# Teknik ML standar seperti Decision Tree dan Logistic Regression memiliki bias terhadap kelas mayoritas, dan cenderung mengabaikan kelas minoritas. Mereka cenderung hanya memprediksi kelas mayoritas, oleh karena itu, memiliki kesalahan klasifikasi yang besar dari kelas minoritas dibandingkan dengan kelas mayoritas.
#
# Dengan kata yang lebih teknis, jika kita memiliki distribusi data yang tidak seimbang dalam kumpulan data kita, maka model kita menjadi lebih rentan terhadap kasus ketika kelas minoritas memiliki ingatan yang dapat diabaikan atau sangat rendah.

# %%
# Handling imbalanced using SMOTE
smote = SMOTE()
x_sm,y_sm = smote.fit_resample(X_final,y)

# %% [markdown]
# # Split Data into train & test data train 90%, data tes 10%

# %%
X_train , X_test , y_train , y_test = train_test_split(x_sm , y_sm , test_size=0.1,random_state=3)

# %% [markdown]
# # MODELLING

# %% [markdown]
# ## Random Forest

# %%
random_forest_classifier = RandomForestClassifier()
random_forest_classifier.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
RandomForestClassifier()
# Out:
# RandomForestClassifier()

# %%
random_forest_classifier_prediction =  random_forest_classifier.predict(X_test)

# %%
accuracy_score(random_forest_classifier_prediction,y_test)
# Out:
# 0.8828320802005013

# %% [markdown]
# # Support vector machine

# %%
svm = SVC()
svm.fit(X_train,y_train)
# Out:
# SVC()

# %%
svm_prediction =  svm.predict(X_test)

# %%
accuracy_score(svm_prediction,y_test)
# Out:
# 0.8740601503759399

# %% [markdown]
# # Naive Bayes

# %%
nb = MultinomialNB()
nb.fit(X_train,y_train)
# Out:
# MultinomialNB()

# %%
nb_prediction =  nb.predict(X_test)

# %%
accuracy_score(nb_prediction,y_test)
# Out:
# 0.7199248120300752

# %% [markdown]
# # Split Data into train & test data train 80%, data tes 20%

# %%
X_train , X_test , y_train , y_test = train_test_split(x_sm , y_sm , test_size=0.2,random_state=3)

# %% [markdown]
# ## Random Forest

# %%
random_forest_classifier = RandomForestClassifier()
random_forest_classifier.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
RandomForestClassifier()
# Out:
# RandomForestClassifier()

# %%
random_forest_classifier_prediction =  random_forest_classifier.predict(X_test)

# %%
accuracy_score(random_forest_classifier_prediction,y_test)
# Out:
# 0.8737468671679198

# %% [markdown]
# # Support vector machine

# %%
svm = SVC()
svm.fit(X_train,y_train)
# Out:
# SVC()

# %%
svm_prediction =  svm.predict(X_test)

# %%
accuracy_score(svm_prediction,y_test)
# Out:
# 0.8677944862155389

# %% [markdown]
# # Naive Bayes

# %%
nb = MultinomialNB()
nb.fit(X_train,y_train)
# Out:
# MultinomialNB()

# %%
nb_prediction =  nb.predict(X_test)

# %%
accuracy_score(nb_prediction,y_test)
# Out:
# 0.724624060150376

# %% [markdown]
# # Split Data into train & test data train 70%, data tes 30%

# %%
X_train , X_test , y_train , y_test = train_test_split(x_sm , y_sm , test_size=0.3,random_state=3)

# %% [markdown]
# ## Random Forest

# %%
random_forest_classifier = RandomForestClassifier()
random_forest_classifier.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
RandomForestClassifier()
# Out:
# RandomForestClassifier()

# %%
random_forest_classifier_prediction =  random_forest_classifier.predict(X_test)

# %%
accuracy_score(random_forest_classifier_prediction,y_test)
# Out:
# 0.8657059314954052

# %% [markdown]
# # Support vector machine

# %%
svm = SVC()
svm.fit(X_train,y_train)
# Out:
# SVC()

# %%
svm_prediction =  svm.predict(X_test)

# %%
accuracy_score(svm_prediction,y_test)
# Out:
# 0.8677944862155389

# %% [markdown]
# # Naive Bayes

# %%
nb = MultinomialNB()
nb.fit(X_train,y_train)
# Out:
# MultinomialNB()

# %%
nb_prediction =  nb.predict(X_test)

# %%
accuracy_score(nb_prediction,y_test)
# Out:
# 0.7207602339181286

# %% [markdown]
# # Split Data into train & test data train 60%, data tes 40%

# %%
X_train , X_test , y_train , y_test = train_test_split(x_sm , y_sm , test_size=0.4,random_state=3)

# %%
# Random Forest
random_forest_classifier = RandomForestClassifier()
random_forest_classifier.fit(X_train,y_train)
random_forest_classifier_prediction =  random_forest_classifier.predict(X_test)
accuracy_score(random_forest_classifier_prediction,y_test)
# Out:
# 0.8519736842105263

# %%
# Support vector machine
svm = SVC()
svm.fit(X_train,y_train)
svm_prediction =  svm.predict(X_test)
accuracy_score(svm_prediction,y_test)
# Out:
# 0.856516290726817

# %%
# Naive Bayes

nb = MultinomialNB()
nb.fit(X_train,y_train)
nb_prediction =  nb.predict(X_test)
accuracy_score(nb_prediction,y_test)
# Out:
# 0.7160087719298246

# %%
#split 50,50
X_train , X_test , y_train , y_test = train_test_split(x_sm , y_sm , test_size=0.5,random_state=3)

# %%
# Random Forest
random_forest_classifier = RandomForestClassifier()
random_forest_classifier.fit(X_train,y_train)
random_forest_classifier_prediction =  random_forest_classifier.predict(X_test)
accuracy_score(random_forest_classifier_prediction,y_test)
# Out:
# 0.8406015037593985

# %%
# Support vector machine
svm = SVC()
svm.fit(X_train,y_train)
svm_prediction =  svm.predict(X_test)
accuracy_score(svm_prediction,y_test)
# Out:
# 0.8474937343358396

# %%
# Naive Bayes

nb = MultinomialNB()
nb.fit(X_train,y_train)
nb_prediction =  nb.predict(X_test)
accuracy_score(nb_prediction,y_test)
# Out:
# 0.7086466165413534

# %%
#split 40,60
X_train , X_test , y_train , y_test = train_test_split(x_sm , y_sm , test_size=0.6,random_state=3)

# %%
# Random Forest
random_forest_classifier = RandomForestClassifier()
random_forest_classifier.fit(X_train,y_train)
random_forest_classifier_prediction =  random_forest_classifier.predict(X_test)
accuracy_score(random_forest_classifier_prediction,y_test)
# Out:
# 0.8175647451963242

# %%
# Support vector machine
svm = SVC()
svm.fit(X_train,y_train)
svm_prediction =  svm.predict(X_test)
accuracy_score(svm_prediction,y_test)
# Out:
# 0.829156223893066

# %%
# Naive Bayes

nb = MultinomialNB()
nb.fit(X_train,y_train)
nb_prediction =  nb.predict(X_test)
accuracy_score(nb_prediction,y_test)
# Out:
# 0.6935045948203843

# %%
#split 40,60
X_train , X_test , y_train , y_test = train_test_split(x_sm , y_sm , test_size=0.7,random_state=3)

# %%
# Random Forest
random_forest_classifier = RandomForestClassifier()
random_forest_classifier.fit(X_train,y_train)
random_forest_classifier_prediction =  random_forest_classifier.predict(X_test)
accuracy_score(random_forest_classifier_prediction,y_test)
# Out:
# 0.7949337629788757

# %%
# Support vector machine
svm = SVC()
svm.fit(X_train,y_train)
svm_prediction =  svm.predict(X_test)
accuracy_score(svm_prediction,y_test)
# Out:
# 0.8193698532044397

# %%
# Naive Bayes

nb = MultinomialNB()
nb.fit(X_train,y_train)
nb_prediction =  nb.predict(X_test)
accuracy_score(nb_prediction,y_test)
# Out:
# 0.6873433583959899

# %%
#split 20, 80
X_train , X_test , y_train , y_test = train_test_split(x_sm , y_sm , test_size=0.8,random_state=3)

# Random Forest
random_forest_classifier = RandomForestClassifier()
random_forest_classifier.fit(X_train,y_train)
random_forest_classifier_prediction =  random_forest_classifier.predict(X_test)
accuracy_score(random_forest_classifier_prediction,y_test)
# Out:
# 0.6658834586466166
# 0.7593201754385965

# %%
# Support vector machine
svm = SVC()
svm.fit(X_train,y_train)
svm_prediction =  svm.predict(X_test)
accuracy_score(svm_prediction,y_test)
# Out:
# 0.7920582706766918

# %%
# Naive Bayes

nb = MultinomialNB()
nb.fit(X_train,y_train)
nb_prediction =  nb.predict(X_test)
accuracy_score(nb_prediction,y_test)
# Out:
# 0.6658834586466166

# %%
#split 10, 90
X_train , X_test , y_train , y_test = train_test_split(x_sm , y_sm , test_size=0.9,random_state=3)

# Random Forest
random_forest_classifier = RandomForestClassifier()
random_forest_classifier.fit(X_train,y_train)
random_forest_classifier_prediction =  random_forest_classifier.predict(X_test)
accuracy_score(random_forest_classifier_prediction,y_test)
# Out:
# 0.6995962127541074

# %%
# Support vector machine
svm = SVC()
svm.fit(X_train,y_train)
svm_prediction =  svm.predict(X_test)
accuracy_score(svm_prediction,y_test)
# Out:
# 0.7660122528543581

# %%
# Naive Bayes

nb = MultinomialNB()
nb.fit(X_train,y_train)
nb_prediction =  nb.predict(X_test)
accuracy_score(nb_prediction,y_test)
# Out:
# 0.6388888888888888

# %%
# initialize list of lists
data_akurasi = [[90,10,88.28,87.41,71.99], [80,20,87.37,86.78,72.46],[70,30,86.57,86.78,72.07],[60,40,85.20,85.65,71.60],[50,50,84.06,84.75,70.86],[40,60,81.76,82.92,69.35],[30,70,79.49,81.94,68.73],[20,80,66.59,79.21,66.59],[10,90,69.96,76.60,63.89]]

# Create the pandas DataFrame
df_akurasi = pd.DataFrame(data_akurasi, columns=['data_train', 'data_tes', 'random_fores', 'SVM', 'naive_bayes'])

# print dataframe.
df_akurasi
# Out:
#    data_train  data_tes  random_fores    SVM  naive_bayes
# 0          90        10         88.28  87.41        71.99
# 1          80        20         87.37  86.78        72.46
# 2          70        30         86.57  86.78        72.07
# 3          60        40         85.20  85.65        71.60
# 4          50        50         84.06  84.75        70.86
# 5          40        60         81.76  82.92        69.35
# 6          30        70         79.49  81.94        68.73
# 7          20        80         66.59  79.21        66.59
# 8          10        90         69.96  76.60        63.89

# %%
# Importing packages
import matplotlib.pyplot as plt

# %%
plt.plot(df_akurasi['data_train'], df_akurasi['random_fores'], 'g', label='Random Forest')
plt.plot(df_akurasi['data_train'], df_akurasi['SVM'], 'r', label='SVM')
plt.plot(df_akurasi['data_train'], df_akurasi['naive_bayes'], 'y', label='Naive Bayes')
plt.xlabel('Jumlah Data Train dalam %', fontsize=18)
plt.ylabel('Nilai Akurasi dalam %', fontsize=16)
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

#sorting berdasarkan data train ascending
df_akurasi = df_akurasi.sort_values(by='data_train', ascending=True)
# set width of bar
barWidth = 0.3
fig = plt.subplots(figsize =(12, 8))

# set height of bar
#IT = [12, 30, 1, 8, 22]
#ECE = [28, 6, 16, 5, 10]
#CSE = [29, 3, 24, 25, 17]

# Set position of bar on X axis
br1 = np.arange(len(df_akurasi['random_fores']))
br2 = [x + barWidth for x in br1]
br3 = [x + barWidth for x in br2]

# Make the plot
plt.bar(br1, df_akurasi['random_fores'], color ='orange', width = barWidth,
		edgecolor ='grey', label ='Random Forest')
plt.bar(br2, df_akurasi['SVM'], color ='b', width = barWidth,
		edgecolor ='grey', label ='svm')
plt.bar(br3, df_akurasi['naive_bayes'], color ='magenta', width = barWidth,
		edgecolor ='grey', label ='Naive Bayes')

plt.ylim(40, 90)
# Adding Xticks
plt.xlabel('Data Train dalam %', fontweight ='bold', fontsize = 15)
plt.ylabel('Akurasi dalam %', fontweight ='bold', fontsize = 15)
plt.xticks([r + barWidth for r in range(len(df_akurasi['random_fores']))],
		df_akurasi['data_train'])

plt.legend()
plt.show()

# %% [markdown]
# # Frequency distributions

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist

words = nltk.word_tokenize(all_words_lem)
fd = FreqDist(words)

# %% [markdown]
# # Most common words

# %%
fd.most_common(3)
# Out:
# [('aplikasi', 1254), ('gojek', 981), ('bantu', 851)]

# %%
fd.tabulate(3)
# Out:
# aplikasi    gojek    bantu
#     1254      981      851

# %% [markdown]
# # Plot common words

# %%
# Obtain top 10 words
top_10 = fd.most_common(10)

# Create pandas series to make plotting easier
fdist = pd.Series(dict(top_10))

# %%
import seaborn as sns
sns.set_theme(style="ticks")

sns.barplot(y=fdist.index, x=fdist.values, color='blue');

# %%
import plotly.express as px

fig = px.bar(y=fdist.index, x=fdist.values)

# sort values
fig.update_layout(barmode='stack', yaxis={'categoryorder':'total ascending'})

# show plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="b6360349-74de-4115-a1e8-5510f7d62999" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b6360349-74de-4115-a1e8-5510f7d62999")) {                    Plotly.newPlot(                        "b6360349-74de-4115-a1e8-5510f7d62999",                        [{"alignmentgroup":"True","hovertemplate":"x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[524,447,359,319,260,233,216,211,208,195],"xaxis":"x","y":["aplikasi","nya","gojek","gak","driver","voucher","promo","aja","tolong","udah"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":"" ...
